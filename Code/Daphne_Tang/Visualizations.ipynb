# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv("data.csv")
df.head()
# Out:
#    valence  year  acousticness  \
# 0   0.0594  1921         0.982
# 1   0.9630  1921         0.732
# 2   0.0394  1921         0.961
# 3   0.1650  1921         0.967
# 4   0.2530  1921         0.957
#
#                                              artists  danceability  \
# 0  ['Sergei Rachmaninoff', 'James Levine', 'Berli...         0.279
# 1                                     ['Dennis Day']         0.819
# 2  ['KHP Kridhamardawa Karaton Ngayogyakarta Hadi...         0.328
# 3                                   ['Frank Parker']         0.275
# 4                                     ['Phil Regan']         0.418
#
#    duration_ms  energy  explicit                      id  instrumentalness  \
# 0       831667   0.211         0  4BJqT0PrAfrxzMOxytFOIz          0.878000
# 1       180533   0.341         0  7xPhfUan2yNtyFG0cUWkt8          0.000000
# 2       500062   0.166         0  1o6I8BglA6ylDMrIELygv1          0.913000
# ...

# %%
df_artist = pd.read_csv("data_by_artist.csv")
df_artist.head()
# Out:
#    mode  count  acousticness  \
# 0     1      9      0.590111
# 1     1     26      0.862538
# 2     1      7      0.856571
# 3     1     27      0.884926
# 4     1      7      0.510714
#
#                                              artists  danceability  \
# 0                   "Cats" 1981 Original London Cast      0.467222
# 1                          "Cats" 1983 Broadway Cast      0.441731
# 2        "Fiddler On The Roof” Motion Picture Chorus      0.348286
# 3     "Fiddler On The Roof” Motion Picture Orchestra      0.425074
# 4  "Joseph And The Amazing Technicolor Dreamcoat"...      0.467143
#
#      duration_ms    energy  instrumentalness  liveness   loudness  \
# 0  250318.555556  0.394003          0.011400  0.290833 -14.448000
# 1  287280.000000  0.406808          0.081158  0.315215 -10.690000
# 2  328920.000000  0.286571          0.024593  0.325786 -15.230714
# 3  262890.962963  0.245770          0.073587  0.275481 -15.639370
# ...

# %%
df_genres = pd.read_csv("data_by_genres.csv")
df_genres.head()
# Out:
#    mode                  genres  acousticness  danceability   duration_ms  \
# 0     1  21st century classical      0.979333      0.162883  1.602977e+05
# 1     1                   432hz      0.494780      0.299333  1.048887e+06
# 2     1                   8-bit      0.762000      0.712000  1.151770e+05
# 3     1                      []      0.651417      0.529093  2.328809e+05
# 4     1              a cappella      0.676557      0.538961  1.906285e+05
#
#      energy  instrumentalness  liveness   loudness  speechiness       tempo  \
# 0  0.071317          0.606834  0.361600 -31.514333     0.040567   75.336500
# 1  0.450678          0.477762  0.131000 -16.854000     0.076817  120.285667
# 2  0.818000          0.876000  0.126000  -9.180000     0.047000  133.444000
# 3  0.419146          0.205309  0.218696 -12.288965     0.107872  112.857352
# 4  0.316434          0.003003  0.172254 -12.479387     0.082851  112.110362
#
#     valence  popularity  key
# 0  0.103783   27.833333    6
# ...

# %%
df_year = pd.read_csv("data_by_year.csv")
df_year.head()
# Out:
#    mode  year  acousticness  danceability    duration_ms    energy  \
# 0     1  1921      0.886896      0.418597  260537.166667  0.231815
# 1     1  1922      0.938592      0.482042  165469.746479  0.237815
# 2     1  1923      0.957247      0.577341  177942.362162  0.262406
# 3     1  1924      0.940200      0.549894  191046.707627  0.344347
# 4     1  1925      0.962607      0.573863  184986.924460  0.278594
#
#    instrumentalness  liveness   loudness  speechiness       tempo   valence  \
# 0          0.344878  0.205710 -17.048667     0.073662  101.531493  0.379327
# 1          0.434195  0.240720 -19.275282     0.116655  100.884521  0.535549
# 2          0.371733  0.227462 -14.129211     0.093949  114.010730  0.625492
# 3          0.581701  0.235219 -14.231343     0.092089  120.689572  0.663725
# 4          0.418297  0.237668 -14.146414     0.111918  115.521921  0.621929
#
#    popularity  key
# 0    0.653333    2
# 1    0.140845   10
# 2    5.389189    0
# 3    0.661017   10
# ...

# %%
df_w_genres = pd.read_csv("data_w_genres.csv")
df_w_genres.head()
# Out:
#            genres                                            artists  \
# 0  ['show tunes']                   "Cats" 1981 Original London Cast
# 1              []                          "Cats" 1983 Broadway Cast
# 2              []        "Fiddler On The Roof” Motion Picture Chorus
# 3              []     "Fiddler On The Roof” Motion Picture Orchestra
# 4              []  "Joseph And The Amazing Technicolor Dreamcoat"...
#
#    acousticness  danceability    duration_ms    energy  instrumentalness  \
# 0      0.590111      0.467222  250318.555556  0.394003          0.011400
# 1      0.862538      0.441731  287280.000000  0.406808          0.081158
# 2      0.856571      0.348286  328920.000000  0.286571          0.024593
# 3      0.884926      0.425074  262890.962963  0.245770          0.073587
# 4      0.510714      0.467143  270436.142857  0.488286          0.009400
#
#    liveness   loudness  speechiness       tempo   valence  popularity  key  \
# ...

# %%
df_tcc = pd.read_csv("tcc_ceds_music.csv")
df_tcc.head()
# Out:
#    Unnamed: 0           artist_name            track_name  release_date genre  \
# 0           0                mukesh  mohabbat bhi jhoothi          1950   pop
# 1           4         frankie laine             i believe          1950   pop
# 2           6           johnnie ray                   cry          1950   pop
# 3          10           pérez prado              patricia          1950   pop
# 4          12  giorgos papadopoulos    apopse eida oneiro          1950   pop
#
#                                               lyrics  len    dating  violence  \
# 0  hold time feel break feel untrue convince spea...   95  0.000598  0.063746
# 1  believe drop rain fall grow believe darkest ni...   51  0.035537  0.096777
# 2  sweetheart send letter goodbye secret feel bet...   24  0.002770  0.002770
# 3  kiss lips want stroll charm mambo chacha merin...   54  0.048249  0.001548
# 4  till darling till matter know till dream live ...   48  0.001350  0.001350
#
# ...

# %%
print(f"Shape: {df.shape}\n")

print(f"Dupes?: {df.duplicated().sum()}\n")

print(f"Nulls?: \n{df.isnull().sum()}")
# Out:
# Shape: (170653, 19)
#
# Dupes?: 0
#
# Nulls?:
# valence             0
# year                0
# acousticness        0
# artists             0
# danceability        0
# duration_ms         0
# energy              0
# explicit            0
# id                  0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# name                0
# popularity          0
# release_date        0
# speechiness         0
# tempo               0
# dtype: int64

# %%
df.columns # column names
# Out:
# Index(['valence', 'year', 'acousticness', 'artists', 'danceability',
#        'duration_ms', 'energy', 'explicit', 'id', 'instrumentalness', 'key',
#        'liveness', 'loudness', 'mode', 'name', 'popularity', 'release_date',
#        'speechiness', 'tempo'],
#       dtype='object')

# %%
df.dtypes # data types
# Out:
# valence             float64
# year                  int64
# acousticness        float64
# artists              object
# danceability        float64
# duration_ms           int64
# energy              float64
# explicit              int64
# id                   object
# instrumentalness    float64
# key                   int64
# liveness            float64
# loudness            float64
# mode                  int64
# name                 object
# popularity            int64
# release_date         object
# speechiness         float64
# tempo               float64
# dtype: object

# %% [markdown]
#   ##### Information on the Columns
#   * **Valence**: Measure from 0.0 to 1.0 that describes positivity in tracks.
#   * **Year**: The year in which the track was released.
#   * **Acousticness**: A confidence measure from 0.0 to 1.0 of whether the track is acoustic, higher value is better confidence.
#   * **Artists**: Names of the Artists.
#   * **Danceability**: Describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is most danceable.
#   * **Duration**: Length of song in microseconds
#   * **Energy**: a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy. For example, death metal has high energy, while a Bach prelude scores low on the scale. Perceptual features contributing to this attribute include dynamic range, perceived loudness, timbre, onset rate, and general entropy.
#   * **Explicit**: Value 1 = Explicit, Value 0 = Not Explicit
#   * **id**: Song ID via Spotify
#   * **Instrumentalness**: Predicts whether a track contains no vocals. “Ooh” and “aah” sounds are treated as instrumental in this context. Rap or spoken word tracks are clearly “vocal”. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content. Values above 0.5 are intended to represent instrumental tracks, but confidence is higher as the value approaches 1.0.
#   * **Key**: The estimated overall key of the track. Integers map to pitches using standard Pitch Class notation . E.g. 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.
#   * **Loudness**: The overall loudness of a track in decibels (dB). Loudness values are averaged across the entire track and are useful for comparing relative loudness of tracks. Loudness is the quality of a sound that is the primary psychological correlate of physical strength (amplitude). Values typical range between -60 and 0 db.
#   * **Mode**: Indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0.
#   * **Popularity**: The popularity of the track. The value will be between 0 and 100, with 100 being the most popular. The popularity is calculated by algorithm and is based, in the most part, on the total number of plays the track has had and how recent those plays are. Generally speaking, songs that are being played a lot now will have a higher popularity than songs that were played a lot in the past. Artist and album popularity is derived mathematically from track popularity. Note that the popularity value may lag actual popularity by a few days: the value is not updated in real time.
#   * **Speechiness**: Speechiness detects the presence of spoken words in a track. The more exclusively speech-like the recording (e.g. talk show, audio book, poetry), the closer to 1.0 the attribute value. Values above 0.66 describe tracks that are probably made entirely of spoken words. Values between 0.33 and 0.66 describe tracks that may contain both music and speech, either in sections or layered, including such cases as rap music. Values below 0.33 most likely represent music and other non-speech-like tracks.
#   * **Tempo**: The overall estimated tempo of a track in beats per minute (BPM). In musical terminology, tempo is the speed or pace of a given piece and derives directly from the average beat duration.

# %%
plt.figure(figsize=(10,10))
sns.heatmap(df.corr(),
            annot=True,
            cmap='YlOrRd', #colors
            cbar=True, # colorbar
            linewidths=1,
            square=True,
            fmt='.2f',
            vmin=-1,
            vmax=1)
# Out:
# <ipython-input-12-0e9943d60201>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),
# <Axes: >

# %%
def extract_decade(year):
    decade_start = int(year/10) * 10
    decade = '{}s'.format(decade_start)
    return decade


df['decade'] = df['year'].apply(extract_decade)
df['decade']
# Out:
# 0         1920s
# 1         1920s
# 2         1920s
# 3         1920s
# 4         1920s
#           ...
# 170648    2020s
# 170649    2020s
# 170650    2020s
# 170651    2020s
# 170652    2020s
# Name: decade, Length: 170653, dtype: object

# %%
extract_decade(1938)
# Out:
# '1930s'

# %%
decade_counts = df['decade'].value_counts()
decade_counts
# Out:
# 1970s    20000
# 1990s    19901
# 1950s    19850
# 1980s    19850
# 2010s    19774
# 2000s    19646
# 1960s    19549
# 1940s    15378
# 1930s     9549
# 1920s     5126
# 2020s     2030
# Name: decade, dtype: int64

# %%
decade = px.bar(data_frame=df, x=decade_counts.index, y=decade_counts.values, color=decade_counts.index,
    color_discrete_sequence=px.colors.qualitative.Pastel)
decade.update_layout(
    title='Song Distribution per Decade (Sorted by Highest Count)',
    xaxis_title='Decade',
    yaxis_title='Count',)
decade.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# df_decade = df.groupby('decade')
# df_decade
# decade_sum = df_decade['Value'].sum()

# %%
# sns.set(rc={'figure.figsize':(10,6)})

# # Create the countplot
# sns.countplot(x=df['decade'], data=df)
# plt.title('Data Distribution per Decade')

# %%
sound_features = ['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'valence']

sound_yr_fig = px.line(df_year, x='year', y=sound_features,title='Sound Features Throughout the Years',color_discrete_sequence=px.colors.qualitative.Plotly)
sound_yr_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
acousticness_yr_fig = px.line(df_year, x='year', y='acousticness',title='Acousticness Throughout the Years',color_discrete_sequence=px.colors.qualitative.Plotly)
acousticness_yr_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
danceability_yr_fig = px.line(df_year, x='year', y='danceability',title='Danceability Throughout the Years',color_discrete_sequence=px.colors.qualitative.Plotly)
danceability_yr_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
energy_yr_fig = px.line(df_year, x='year', y='energy',title='Energy Throughout the Years',color_discrete_sequence=px.colors.qualitative.Plotly)
energy_yr_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
instrumentalness_yr_fig = px.line(df_year, x='year', y='instrumentalness',title='Instrumentalness Throughout the Years',color_discrete_sequence=px.colors.qualitative.Plotly)
instrumentalness_yr_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
liveness_yr_fig = px.line(df_year, x='year', y='liveness',title='Liveness Throughout the Years',color_discrete_sequence=px.colors.qualitative.Plotly)
liveness_yr_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
valence_yr_fig = px.line(df_year, x='year', y='valence',title='Valence Throughout the Years',color_discrete_sequence=px.colors.qualitative.Plotly)
valence_yr_fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_genres.columns
# Out:
# Index(['mode', 'genres', 'acousticness', 'danceability', 'duration_ms',
#        'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness',
#        'tempo', 'valence', 'popularity', 'key'],
#       dtype='object')

# %%
print(f'Sum of Unique Genres: {len(df_genres.genres.unique())}')
# Out:
# Sum of Unique Genres: 2973

# %%
top20_genres = df_genres.nlargest(20, 'popularity')

acousticness_per_genre = px.bar(top20_genres, x='genres', y='acousticness', color_discrete_sequence=px.colors.qualitative.Pastel, color='genres')

acousticness_per_genre.update_layout(
    title='Acousticness for Top 20 Genres',)
acousticness_per_genre.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
top20_genres = df_genres.nlargest(20, 'popularity')

danceability_per_genre = px.bar(top20_genres, x='genres', y='danceability', color_discrete_sequence=px.colors.qualitative.Pastel, color='genres')

danceability_per_genre.update_layout(
    title='Danceability for Top 20 Genres',)
danceability_per_genre.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
top20_genres = df_genres.nlargest(20, 'popularity')

energy_per_genre = px.bar(top20_genres, x='genres', y='energy', color_discrete_sequence=px.colors.qualitative.Pastel, color='genres')

energy_per_genre.update_layout(
    title='Energy for Top 20 Genres',)
energy_per_genre.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
top20_genres = df_genres.nlargest(20, 'popularity')

instrumentalness_per_genre = px.bar(top20_genres, x='genres', y='instrumentalness', color_discrete_sequence=px.colors.qualitative.Pastel, color='genres')

instrumentalness_per_genre.update_layout(
    title='Instrumentalness for Top 20 Genres',)
instrumentalness_per_genre.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
top20_genres = df_genres.nlargest(20, 'popularity')

liveness_per_genre = px.bar(top20_genres, x='genres', y='liveness', color_discrete_sequence=px.colors.qualitative.Pastel, color='genres')

liveness_per_genre.update_layout(
    title='Liveness for Top 20 Genres',)
liveness_per_genre.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
top20_genres = df_genres.nlargest(20, 'popularity')

valence_per_genre = px.bar(top20_genres, x='genres', y='valence', color_discrete_sequence=px.colors.qualitative.Pastel, color='genres')

valence_per_genre.update_layout(
    title='Valence for Top 20 Genres',)
valence_per_genre.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
top10_genres = df_genres.nlargest(10, 'popularity')

sound_per_genre = px.bar(top10_genres, x='genres', y=sound_features, barmode='group', color_discrete_sequence=px.colors.qualitative.Plotly)

sound_per_genre.update_layout(
    title='Sound Features for Top 10 Genres',
    bargap=0.35)
sound_per_genre.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_year.columns
# Out:
# Index(['mode', 'year', 'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'liveness', 'loudness', 'speechiness', 'tempo',
#        'valence', 'popularity', 'key'],
#       dtype='object')

# %%
print(f'Sum of Unique Years: {len(df_year.year.unique())}')
# Out:
# Sum of Unique Years: 100

# %%
df_year.nlargest(20, 'popularity')
# Out:
#     mode  year  acousticness  danceability    duration_ms    energy  \
# 98     1  2019      0.278299      0.644814  201024.788096  0.593224
# 99     1  2020      0.219931      0.692904  193728.397537  0.631232
# 97     1  2018      0.267633      0.663500  206001.007133  0.602435
# 96     1  2017      0.286099      0.612217  211115.696787  0.590421
# 95     1  2016      0.284171      0.600202  221396.510295  0.592855
# 94     1  2015      0.253952      0.593774  230029.046606  0.627064
# 93     1  2014      0.249313      0.589948  233728.314713  0.648795
# 92     1  2013      0.257488      0.571148  242267.661437  0.645597
# 90     1  2011      0.273183      0.552867  236998.787308  0.648301
# 89     1  2010      0.242687      0.572488  242811.804563  0.681778
# 91     1  2012      0.249953      0.570882  245807.457584  0.656571
# 88     1  2009      0.261929      0.564190  238140.013265  0.670749
# 85     1  2006      0.279986      0.568230  234042.914359  0.650326
# ...

# %%
filtered_yrs = df_year[(df_year['year'] >= 2011) & (df_year['year'] <= 2020)]

sound_per_year = px.bar(filtered_yrs, x='year', y=sound_features, barmode='group', color_discrete_sequence=px.colors.qualitative.Plotly)

sound_per_year.update_layout(
    title='Sound Features from Years 2011 to 2020',
    bargap=0.35)
sound_per_year.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
filtered_yrs = df_year[(df_year['year'] >= 2001) & (df_year['year'] <= 2010)]

sound_per_year = px.bar(filtered_yrs, x='year', y=sound_features, barmode='group', color_discrete_sequence=px.colors.qualitative.Plotly)

sound_per_year.update_layout(
    title='Sound Features from Years 2001 to 2010',
    bargap=0.35)
sound_per_year.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_artist.columns
# Out:
# Index(['mode', 'count', 'acousticness', 'artists', 'danceability',
#        'duration_ms', 'energy', 'instrumentalness', 'liveness', 'loudness',
#        'speechiness', 'tempo', 'valence', 'popularity', 'key'],
#       dtype='object')

# %%
print(f'Sum of Unique Artists: {len(df_artist.artists.unique())}')
# Out:
# Sum of Unique Artists: 28680

# %%
top10_artists = df_artist.nlargest(10, 'popularity')

sound_per_artist = px.bar(top10_artists, x='artists', y=sound_features, barmode='group', color_discrete_sequence=px.colors.qualitative.Plotly)

sound_per_artist.update_layout(
    title='Sound Features for Top 10 Artists')
sound_per_artist.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
top20_artists = df_artist.nlargest(20, 'popularity')

acousticness_per_artist = px.bar(top20_artists, x='artists', y='acousticness', color_discrete_sequence=px.colors.qualitative.Pastel, color='artists')

acousticness_per_artist.update_layout(
    title='Acousticness for Top 20 Artists')
acousticness_per_artist.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
top20_artists = df_artist.nlargest(20, 'popularity')

danceability_per_artist = px.bar(top20_artists, x='artists', y='danceability', color_discrete_sequence=px.colors.qualitative.Pastel, color='artists')

danceability_per_artist.update_layout(
    title='Danceability for Top 20 Artists')
danceability_per_artist.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
top20_artists = df_artist.nlargest(20, 'popularity')

energy_per_artist = px.bar(top20_artists, x='artists', y='energy', color_discrete_sequence=px.colors.qualitative.Pastel, color='artists')

energy_per_artist.update_layout(
    title='Energy for Top 20 Artists')
energy_per_artist.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
top20_artists = df_artist.nlargest(20, 'popularity')

instrumentalness_per_artist = px.bar(top20_artists, x='artists', y='instrumentalness', color_discrete_sequence=px.colors.qualitative.Pastel, color='artists')

instrumentalness_per_artist.update_layout(
    title='Instrumentalness for Top 20 Artists')
instrumentalness_per_artist.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
top20_artists = df_artist.nlargest(20, 'popularity')

liveness_per_artist = px.bar(top20_artists, x='artists', y='liveness', color_discrete_sequence=px.colors.qualitative.Pastel, color='artists')

liveness_per_artist.update_layout(
    title='Liveness for Top 20 Artists')
liveness_per_artist.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
top20_artists = df_artist.nlargest(20, 'popularity')

valence_per_artist = px.bar(top20_artists, x='artists', y='valence', color_discrete_sequence=px.colors.qualitative.Pastel, color='artists')

valence_per_artist.update_layout(
    title='Valence for Top 20 Artists')
valence_per_artist.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
